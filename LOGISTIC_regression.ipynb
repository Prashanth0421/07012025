# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashanth0421/07012025/blob/main/LOGISTIC_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import pickle as load
import pickle as dump

# %%
file_name = "/content/claimants.csv"

# %%
df =pd.read_csv(file_name)

# %%
df
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# ...       ...       ...     ...       ...       ...     ...     ...
# 1335    34100         1     0.0       1.0       0.0     NaN   0.576
# 1336    34110         0     1.0       1.0       0.0    46.0   3.705
# 1337    34113         1     1.0       1.0       0.0    39.0   0.099
# 1338    34145         0     1.0       0.0       0.0     8.0   3.177
# 1339    34153         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 7 columns]

# %%
correlation = df['ATTORNEY'].corr(df['LOSS'])
correlation
# Out:
# -0.2197150271023389

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x=df['ATTORNEY'],y=df['LOSS'])
plt.title('correlation between ATTORNEY and LOSS')
plt.xlabel('ATTORNEY')
plt.ylabel('LOSS')
plt.show()
